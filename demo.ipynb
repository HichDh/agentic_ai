# %% [markdown]
# # agentic_rag_lora Demo
#
# This notebook shows indexing and asking a question via Python API.

# %%
from agentic_rag_lora.retriever import Retriever
from agentic_rag_lora.agent import Agent
r = Retriever()
r.index_folder('data/raw')
agent = Agent()
res = agent.ask('What is agentic RAG?')
res['answer'][:500], res['sources'][:2]
